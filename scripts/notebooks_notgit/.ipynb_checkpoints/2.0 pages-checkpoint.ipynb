# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
plt.style.use('ggplot')

df = pd.read_csv('~/Downloads/ga.csv')

# %%
df['pagePathNormal'] = df['pagePath'].apply(lambda x: x.split('?')[0])

# %%
t = df.groupby(['pagePathNormal', 'cd1'])

# %%
res = t.first()

# %% [markdown]
# ## Number of pages in Adobe analytics

# %%
# Number of pages in 2.0
len(df['cd1'].unique())
# Out:
# 17344

# %% [markdown]
# ## Number of pages in en-ie

# %%
# Number of english pages
df = df.dropna()
df = df.dropna(subset=['cd4'])
en = df[df['cd4'].str.contains('en-ie')]
en = en.drop_duplicates(subset=['cd1'])
it = df[df['cd4'].str.contains('it-it')]
it = it.drop_duplicates(subset=['cd1'])

en.shape
# Out:
# (1594, 7)

# %% [markdown]
# ## Pages by category

# %%
# Page categories
def grouppages(x):
    return x.split(':')[0]
en['category'] = en['cd1'].apply(grouppages)
it['category'] = it['cd1'].apply(grouppages)

en['category'].value_counts().reset_index()
# Out:
#              index  category
# 0          flights       898
# 1    travel expert       252
# 2      useful-info       226
# 3        plan-trip       104
# 4       management        24
# 5          booking        17
# 6          checkin        15
# 7             none        10
# 8   screenscrapers         9
# 9        corporate         7
# 10       myryanair         7
# 11           rooms         6
# 12      refundfaqs         4
# 13    gift-voucher         3
# 14          header         3
# 15  inside-ryanair         2
# 16        register         1
# 17   special-offer         1
# 18  getting-around         1
# 19           login         1
# 20       samsonite         1
# 21  travel-updates         1
# 22   group-booking         1

# %% [markdown]
# ## Tagging scope

# %%
def scope(x):
    if x == 'flights':
        return 'SEO pages'
    elif x == 'travel expert':
        return 'TSN'
    else:
        return '2.0'
en['category_group'] = en['category'].apply(scope)
it['category_group'] = it['category'].apply(scope)

en['category_group'].value_counts().reset_index()
# Out:
#        index  category_group
# 0  SEO pages             898
# 1        2.0             444
# 2        TSN             252

# %% [markdown]
# ## Type of 2.0 pages

# %%
def cd1scope(x):
    return x.split(':')[0]
#en['cd1'].apply(cd1scope).value_counts()
en[en['category_group'].str.contains('2.0')]['cd1'].apply(cd1scope).value_counts().reset_index()
# Out:
#              index  cd1
# 0      useful-info  226
# 1        plan-trip  104
# 2       management   24
# 3          booking   17
# 4          checkin   15
# 5             none   10
# 6   screenscrapers    9
# 7        corporate    7
# 8        myryanair    7
# 9            rooms    6
# 10      refundfaqs    4
# 11    gift-voucher    3
# 12          header    3
# 13  inside-ryanair    2
# 14   special-offer    1
# 15  travel-updates    1
# 16           login    1
# 17  getting-around    1
# 18        register    1
# 19   group-booking    1
# 20       samsonite    1

# %% [markdown]
# ## Review by category

# %%
en[en['category'].str.contains('none')]
# Out:
#         UniqueSessions                         cd1  \
# 724                  1         none: resetpassword
# 1121                 1  none: fare_finder: results
# 1341                 1  none: fare_finder: details
# 1520                 1             none: route_map
# 1893                 1              none: redirect
# 8872                 1           none: fare_finder
# 210299               2        none: forgotpassword
# 331143               2            none: timetables
# 341912            6405              none: homepage
# 344171             420            none: route-list
#
#                                                cd2           cd3    cd4  \
# 724            website: en-ie: none: resetpassword  ver.spa-beta  en-ie
# 1121    website: en-ie: none: fare_finder: results  ver.spa-beta  en-ie
# 1341    website: en-ie: none: fare_finder: details  ver.spa-beta  en-ie
# 1520               website: en-ie: none: route_map  ver.spa-beta  en-ie
# 1893                website: en-ie: none: redirect  ver.spa-beta  en-ie
# 8872             website: en-ie: none: fare_finder  ver.spa-beta  en-ie
# 210299        website: en-ie: none: forgotpassword  ver.spa-beta  en-ie
# 331143            website: en-ie: none: timetables  ver.spa-beta  en-ie
# 341912              website: en-ie: none: homepage  ver.spa-beta  en-ie
# 344171            website: en-ie: none: route-list  ver.spa-beta  en-ie
#
#                                                  pagePath  \
# 724     /ie/en/reset/66e27153-3779-4de3-861e-1ff84c1119aa
# 1121    /ie/en/cheap-flights/edinburgh-to-brussels-cha...
# 1341    /ie/en/cheap-flights/dublin-to-seville?out-fro...
# 1520    /ie/en/cheap-flights/london-stansted-to-vienna...
# 1893    /ie/en/redirect?booking=WSG7YSGYMPS4JSKNAP56UF...
# 8872    /ie/en/cheap-flights/?from=BTS&out-from-date=2...
# 210299                             /ie/en/mytrips/summary
# 331143                                    /ie/en/check-in
# 341912                                            /ie/en/
# 344171              /ie/en/cheap-flight-destinations-list
#
#                                            pagePathNormal category  \
# 724     /ie/en/reset/66e27153-3779-4de3-861e-1ff84c1119aa     none
# 1121    /ie/en/cheap-flights/edinburgh-to-brussels-cha...     none
# 1341               /ie/en/cheap-flights/dublin-to-seville     none
# 1520       /ie/en/cheap-flights/london-stansted-to-vienna     none
# 1893                                      /ie/en/redirect     none
# 8872                                /ie/en/cheap-flights/     none
# 210299                             /ie/en/mytrips/summary     none
# 331143                                    /ie/en/check-in     none
# 341912                                            /ie/en/     none
# 344171              /ie/en/cheap-flight-destinations-list     none
#
#        category_group
# 724               2.0
# 1121              2.0
# 1341              2.0
# 1520              2.0
# 1893              2.0
# 8872              2.0
# 210299            2.0
# 331143            2.0
# 341912            2.0
# 344171            2.0

# %% [markdown]
# - 2.0 pages should we keep the value none?

# %%
en[en['category'].str.contains('plan-trip')]
# Out:
#          UniqueSessions                                                cd1  \
# 6194                  1                    plan-trip: travel-documentation
# 9754                  1              plan-trip: flying-with-us: my-ryanair
# 13825                 1         plan-trip: explore: flight-deals-and-sales
# 23197                 1                   plan-trip: explore: cyber-week-6
# 36262                 1                       plan-trip: explore: getaways
# ...                 ...                                                ...
# 4054855               1   plan-trip: travel-extras: ryanair-car-hire: cork
# 4876779               1                   plan-trip: explore: cyber-week-4
# 4980318               1  plan-trip: travel-extras: ryanair-car-hire: ha...
# 4980762               1  plan-trip: travel-extras: ryanair-car-hire: co...
# 5014572               1                   plan-trip: explore: cheap-deals:
#
#                                                        cd2           cd3  \
# 6194       website: en-ie: plan-trip: travel-documentation  ver.spa-beta
# 9754     website: en-ie: plan-trip: flying-with-us: my-...  ver.spa-beta
# 13825    website: : plan-trip: explore: flight-deals-an...  ver.spa-beta
# 23197     website: en-ie: plan-trip: explore: cyber-week-6  ver.spa-beta
# 36262         website: en-ie: plan-trip: explore: getaways  ver.spa-beta
# ...                                                    ...           ...
# 4054855  website: : plan-trip: travel-extras: ryanair-c...  ver.spa-beta
# 4876779   website: en-ie: plan-trip: explore: cyber-week-4  ver.spa-beta
# 4980318  website: : plan-trip: travel-extras: ryanair-c...  ver.spa-beta
# 4980762  website: : plan-trip: travel-extras: ryanair-c...  ver.spa-beta
# 5014572       website: : plan-trip: explore: cheap-deals:   ver.spa-beta
#
#            cd4                                           pagePath  \
# 6194     en-ie  /ie/en/plan-trip/travel-documentation?fbclid=I...
# 9754     en-ie  /ie/en/plan-trip/flying-with-us/my-ryanair?cmp...
# 13825    en-ie  /ie/en/plan-trip/explore/flight-deals-and-sale...
# 23197    en-ie  /ie/en/plan-trip/explore/cyber-week-6?onsid=ry...
# 36262    en-ie  /ie/en/plan-trip/explore/getaways?cmpid=email_...
# ...        ...                                                ...
# 4054855  en-ie  /ie/en/plan-trip/travel-extras/ryanair-car-hir...
# 4876779  en-ie              /ie/en/plan-trip/explore/cyber-week-4
# 4980318  en-ie  /ie/en/plan-trip/travel-extras/ryanair-car-hir...
# 4980762  en-ie  /ie/en/plan-trip/travel-extras/ryanair-car-hir...
# 5014572  en-ie  /ie/en/plan-trip/explore/cheap-deals/?cmpid=em...
#
#                                             pagePathNormal   category  \
# 6194                 /ie/en/plan-trip/travel-documentation  plan-trip
# 9754            /ie/en/plan-trip/flying-with-us/my-ryanair  plan-trip
# 13825      /ie/en/plan-trip/explore/flight-deals-and-sales  plan-trip
# 23197                /ie/en/plan-trip/explore/cyber-week-6  plan-trip
# 36262                    /ie/en/plan-trip/explore/getaways  plan-trip
# ...                                                    ...        ...
# 4054855  /ie/en/plan-trip/travel-extras/ryanair-car-hir...  plan-trip
# 4876779              /ie/en/plan-trip/explore/cyber-week-4  plan-trip
# 4980318  /ie/en/plan-trip/travel-extras/ryanair-car-hir...  plan-trip
# 4980762  /ie/en/plan-trip/travel-extras/ryanair-car-hir...  plan-trip
# 5014572              /ie/en/plan-trip/explore/cheap-deals/  plan-trip
#
#         category_group
# 6194               2.0
# 9754               2.0
# 13825              2.0
# 23197              2.0
# 36262              2.0
# ...                ...
# 4054855            2.0
# 4876779            2.0
# 4980318            2.0
# 4980762            2.0
# 5014572            2.0
#
# [104 rows x 9 columns]

# %% [markdown]
# ## Plan trip
#
# Break down:
#
# https://www.ryanair.com/fr/fr/planifier-un-voyage/destinations/vols-pour-gerone
#
# to
#
# website: : planifier-un-voyage: destinations: vols-pour
#
# https://www.ryanair.com/ie/en/plan-trip/explore/flight-deals-and-sales
#
# to website: : plan-trip: explore: flight-deals-and-sales
#
# Similar for all the other "translated hits"

# %%
en[en['category_group'].str.contains('SEO pages')]
# Out:
#          UniqueSessions                                       cd1  \
# 11926                 1     flights: flights-from-naples-to-milan
# 29863                 1  flights: flights-from-milan-to-barcelona
# 44892                 1  flights: flights-from-lisbon-to-budapest
# 46797                 1  flights: flights-from-bucharest-to-milan
# 48650                 1   flights: flights-from-dublin-to-mykonos
# ...                 ...                                       ...
# 4991067               1       flights: flights-from-cork-to-zadar
# 5002001               1    flights: flights-from-hamburg-to-zadar
# 5013378               1             flights: flights-to-nuremberg
# 5030878               1  flights: flights-from-krakow-to-brindisi
# 5031118               1       flights: flights-from-nis-to-berlin
#
#                                                        cd2           cd3  \
# 11926    website: en-ie: flights: flights-from-naples-t...  ver.spa-beta
# 29863    website: en-ie: flights: flights-from-milan-to...  ver.spa-beta
# 44892    website: en-ie: flights: flights-from-lisbon-t...  ver.spa-beta
# 46797    website: en-ie: flights: flights-from-buchares...  ver.spa-beta
# 48650    website: en-ie: flights: flights-from-dublin-t...  ver.spa-beta
# ...                                                    ...           ...
# 4991067  website: en-ie: flights: flights-from-cork-to-...  ver.spa-beta
# 5002001  website: en-ie: flights: flights-from-hamburg-...  ver.spa-beta
# 5013378      website: en-ie: flights: flights-to-nuremberg  ver.spa-beta
# 5030878  website: en-ie: flights: flights-from-krakow-t...  ver.spa-beta
# 5031118  website: en-ie: flights: flights-from-nis-to-b...  ver.spa-beta
#
#            cd4                                        pagePath  \
# 11926    en-ie     /flights/ie/en/flights-from-naples-to-milan
# 29863    en-ie  /flights/ie/en/flights-from-milan-to-barcelona
# 44892    en-ie  /flights/ie/en/flights-from-lisbon-to-budapest
# 46797    en-ie  /flights/ie/en/flights-from-bucharest-to-milan
# 48650    en-ie   /flights/ie/en/flights-from-dublin-to-mykonos
# ...        ...                                             ...
# 4991067  en-ie       /flights/ie/en/flights-from-cork-to-zadar
# 5002001  en-ie    /flights/ie/en/flights-from-hamburg-to-zadar
# 5013378  en-ie             /flights/ie/en/flights-to-nuremberg
# 5030878  en-ie  /flights/ie/en/flights-from-krakow-to-brindisi
# 5031118  en-ie       /flights/ie/en/flights-from-nis-to-berlin
#
#                                          pagePathNormal category  \
# 11926       /flights/ie/en/flights-from-naples-to-milan  flights
# 29863    /flights/ie/en/flights-from-milan-to-barcelona  flights
# 44892    /flights/ie/en/flights-from-lisbon-to-budapest  flights
# 46797    /flights/ie/en/flights-from-bucharest-to-milan  flights
# 48650     /flights/ie/en/flights-from-dublin-to-mykonos  flights
# ...                                                 ...      ...
# 4991067       /flights/ie/en/flights-from-cork-to-zadar  flights
# 5002001    /flights/ie/en/flights-from-hamburg-to-zadar  flights
# 5013378             /flights/ie/en/flights-to-nuremberg  flights
# 5030878  /flights/ie/en/flights-from-krakow-to-brindisi  flights
# 5031118       /flights/ie/en/flights-from-nis-to-berlin  flights
#
#         category_group
# 11926        SEO pages
# 29863        SEO pages
# 44892        SEO pages
# 46797        SEO pages
# 48650        SEO pages
# ...                ...
# 4991067      SEO pages
# 5002001      SEO pages
# 5013378      SEO pages
# 5030878      SEO pages
# 5031118      SEO pages
#
# [898 rows x 9 columns]

# %%
## Control for SEO pages
it[it['category_group'].str.contains('SEO pages')]
# Out:
#          UniqueSessions                                         cd1  \
# 1537                  1         flights: voli-da-lisbona-a-cagliari
# 2037                  1            flights: voli-da-genova-a-napoli
# 24158                 1            flights: voli-da-varsavia-a-pisa
# 30973                 1     flights: voli-da-copenaghen-a-charleroi
# 41618                 1        flights: voli-da-stoccarda-a-alghero
# ...                 ...                                         ...
# 5033492               1        flights: voli-da-bergamo-a-santander
# 5034377               1                 flights: voli-a-cote-d'azur
# 5041884               1            flights: voli-da-trapani-a-praga
# 5043596               1  flights: voli-da-lamezia-terme-a-saragozza
# 5080500               1      flights: voli-da-barcellona-a-brindisi
#
#                                                        cd2           cd3  \
# 1537     website: it-it: flights: voli-da-lisbona-a-cag...  ver.spa-beta
# 2037      website: it-it: flights: voli-da-genova-a-napoli  ver.spa-beta
# 24158     website: it-it: flights: voli-da-varsavia-a-pisa  ver.spa-beta
# 30973    website: it-it: flights: voli-da-copenaghen-a-...  ver.spa-beta
# 41618    website: it-it: flights: voli-da-stoccarda-a-a...  ver.spa-beta
# ...                                                    ...           ...
# 5033492  website: it-it: flights: voli-da-bergamo-a-san...  ver.spa-beta
# 5034377        website: it-it: flights: voli-a-cote-d'azur  ver.spa-beta
# 5041884   website: it-it: flights: voli-da-trapani-a-praga  ver.spa-beta
# 5043596  website: it-it: flights: voli-da-lamezia-terme...  ver.spa-beta
# 5080500  website: it-it: flights: voli-da-barcellona-a-...  ver.spa-beta
#
#            cd4                                           pagePath  \
# 1537     it-it          /flights/it/it/voli-da-lisbona-a-cagliari
# 2037     it-it  /flights/it/it/voli-da-genova-a-napoli?fbclid=...
# 24158    it-it             /flights/it/it/voli-da-varsavia-a-pisa
# 30973    it-it      /flights/it/it/voli-da-copenaghen-a-charleroi
# 41618    it-it         /flights/it/it/voli-da-stoccarda-a-alghero
# ...        ...                                                ...
# 5033492  it-it         /flights/it/it/voli-da-bergamo-a-santander
# 5034377  it-it                  /flights/it/it/voli-a-cote-d'azur
# 5041884  it-it             /flights/it/it/voli-da-trapani-a-praga
# 5043596  it-it   /flights/it/it/voli-da-lamezia-terme-a-saragozza
# 5080500  it-it       /flights/it/it/voli-da-barcellona-a-brindisi
#
#                                            pagePathNormal category  \
# 1537            /flights/it/it/voli-da-lisbona-a-cagliari  flights
# 2037               /flights/it/it/voli-da-genova-a-napoli  flights
# 24158              /flights/it/it/voli-da-varsavia-a-pisa  flights
# 30973       /flights/it/it/voli-da-copenaghen-a-charleroi  flights
# 41618          /flights/it/it/voli-da-stoccarda-a-alghero  flights
# ...                                                   ...      ...
# 5033492        /flights/it/it/voli-da-bergamo-a-santander  flights
# 5034377                 /flights/it/it/voli-a-cote-d'azur  flights
# 5041884            /flights/it/it/voli-da-trapani-a-praga  flights
# 5043596  /flights/it/it/voli-da-lamezia-terme-a-saragozza  flights
# 5080500      /flights/it/it/voli-da-barcellona-a-brindisi  flights
#
#         category_group
# 1537         SEO pages
# 2037         SEO pages
# 24158        SEO pages
# 30973        SEO pages
# 41618        SEO pages
# ...                ...
# 5033492      SEO pages
# 5034377      SEO pages
# 5041884      SEO pages
# 5043596      SEO pages
# 5080500      SEO pages
#
# [1615 rows x 9 columns]

# %% [markdown]
# ## Pages left in 2.0

# %%
en[en['category_group'].str.contains('2.0')]['cd1'].apply(cd1scope).value_counts().reset_index().drop([0,1]).sum()
# Out:
# index    managementbookingcheckinnonescreenscraperscorp...
# cd1                                                    114
# dtype: object

# %%
en[en['category_group'].str.contains('2.0')].reset_index()
# Out:
#        index  UniqueSessions  \
# 0          3               1
# 1          4               1
# 2         18               1
# 3         19               1
# 4         36               1
# ..       ...             ...
# 439  4876779               1
# 440  4910969               1
# 441  4980318               1
# 442  4980762               1
# 443  5014572               1
#
#                                                    cd1  \
# 0                                      checkin: select
# 1                           checkin: priority-boarding
# 2                              management: active_trip
# 3            management: flightchange: confirm and pay
# 4                                  checkin: allocation
# ..                                                 ...
# 439                   plan-trip: explore: cyber-week-4
# 440             useful-info: travelling-with-children:
# 441  plan-trip: travel-extras: ryanair-car-hire: ha...
# 442  plan-trip: travel-extras: ryanair-car-hire: co...
# 443                   plan-trip: explore: cheap-deals:
#
#                                                    cd2           cd3    cd4  \
# 0                      website: en-ie: checkin: select  ver.spa-beta  en-ie
# 1           website: en-ie: checkin: priority-boarding  ver.spa-beta  en-ie
# 2              website: en-ie: management: active_trip  ver.spa-beta  en-ie
# 3    website: en-ie: management: flightchange: conf...  ver.spa-beta  en-ie
# 4                  website: en-ie: checkin: allocation  ver.spa-beta  en-ie
# ..                                                 ...           ...    ...
# 439   website: en-ie: plan-trip: explore: cyber-week-4  ver.spa-beta  en-ie
# 440  website: : useful-info: travelling-with-childr...  ver.spa-beta  en-ie
# 441  website: : plan-trip: travel-extras: ryanair-c...  ver.spa-beta  en-ie
# 442  website: : plan-trip: travel-extras: ryanair-c...  ver.spa-beta  en-ie
# 443       website: : plan-trip: explore: cheap-deals:   ver.spa-beta  en-ie
#
#                                               pagePath  \
# 0    /ie/en/booking/active/checkin?tripId=93963238-...
# 1    /ie/en/booking/active/checkin?tripId=f6fab10c-...
# 2    /ie/en/booking/active/manage-trip/home?tripId=...
# 3    /ie/en/booking/active/manage-trip/change-fligh...
# 4    /ie/en/booking/active/checkin?tripId=TripBased...
# ..                                                 ...
# 439              /ie/en/plan-trip/explore/cyber-week-4
# 440       /ie/en/useful-info/travelling-with-children/
# 441  /ie/en/plan-trip/travel-extras/ryanair-car-hir...
# 442  /ie/en/plan-trip/travel-extras/ryanair-car-hir...
# 443  /ie/en/plan-trip/explore/cheap-deals/?cmpid=em...
#
#                                         pagePathNormal     category  \
# 0                        /ie/en/booking/active/checkin      checkin
# 1                        /ie/en/booking/active/checkin      checkin
# 2               /ie/en/booking/active/manage-trip/home   management
# 3      /ie/en/booking/active/manage-trip/change-flight   management
# 4                        /ie/en/booking/active/checkin      checkin
# ..                                                 ...          ...
# 439              /ie/en/plan-trip/explore/cyber-week-4    plan-trip
# 440       /ie/en/useful-info/travelling-with-children/  useful-info
# 441  /ie/en/plan-trip/travel-extras/ryanair-car-hir...    plan-trip
# 442  /ie/en/plan-trip/travel-extras/ryanair-car-hir...    plan-trip
# 443              /ie/en/plan-trip/explore/cheap-deals/    plan-trip
#
#     category_group
# 0              2.0
# 1              2.0
# 2              2.0
# 3              2.0
# 4              2.0
# ..             ...
# 439            2.0
# 440            2.0
# 441            2.0
# 442            2.0
# 443            2.0
#
# [444 rows x 10 columns]

# %% [markdown]
# ## Questions
#
# - Should we keep the translated version of the pages?
#     - How do you manage then to attribute conversion to a specific page?
#
# - Can we apply the same logic for all the other 2.0 pages?
#     - How do we structure then management/booking/checkin/none pages?
#
# - If we are not going with a translated version how do we identify a page?
