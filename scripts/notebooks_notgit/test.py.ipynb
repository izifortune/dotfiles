# %%
import numpy as np

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/79a6e869-ffec-4b8c-b0e2-f2e4df257dc6.csv')

# %%
df['datetime'] = pd.to_datetime(df['date'] + ' ' + df['time'], format="%Y-%m-%d %H:%M:%S")

# %%
grouped = df.groupby('querystring')

# %%
grouped.size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='querystring'>
