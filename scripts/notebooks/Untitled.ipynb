# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
plt.style.use('ggplot')

df = pd.read_csv('~/Downloads/catalog-api-referrer.csv')

# %%
# Out:
#       total  day                       ref
# 0        61   12  https://www.ryanair.com/
# 1    106532    9                     seats
# 2     24741    8              checkin bags
# 3       668   10           userprofile-api
# 4    240071   10                         -
# ..      ...  ...                       ...
# 148  111238    8                   payment
# 149   16175   12              checkin paxs
# 150    6217   13                person-api
# 151  202516   12                         -
# 152     258   14            getting around
#
# [153 rows x 3 columns]

# %%
df.groupby(['ref']).sum().sort_values(by='total', ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='ref'>

# %%
df.groupby(['ref']).sum().sort_values(by='total', ascending=False)
# Out:
#                                         total  day
# ref
# bags                                  2739180   84
# -                                     1623802   84
# extras                                 948311   84
# seats                                  851705   84
# payment                                838698   84
# booking-api                            164379   84
# checkin paxs                           139328   84
# checkin bags                           137104   84
# catalog-api                             95773   84
# basket-api                              95585   84
# checkin extras                          85452   84
# checkin seats                           61803   84
# person-api                              39225   84
# userprofile-api                          6150   84
# https://www.ryanair.com/gb/en            4782   84
# checkin flights                          3395   84
# getting around                           2942   84
# ...
